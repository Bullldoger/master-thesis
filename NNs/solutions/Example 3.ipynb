# %%
import pden
import pden.Net
import pden.Operations
import pden.PDENet

import tensorflow as tf

import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from IPython.display import clear_output

# %load_ext autoreload
# %autoreload 1

# %aimport pden.Net
# %aimport pden.Operations
# %aimport pden.PDENet

# %%
def der(y, x, y_shape: int, x_shape: int):
    ys = tf.split(y, [1] * y_shape, 1)
    def _der(i, j=[]):
        f = ys[i]
        for _j in j:
            fs = tf.gradients(f, x)[0]
            f  = tf.split(fs, [1] * x_shape, 1)[_j]        
        return f
    return _der

# %%
k = 4
net = pden.Net.BasicNet(
    pden.Operations.Linear(feature_out=k, random_init = True),
    pden.Operations.ActivationFunction(tf.nn.tanh),
    pden.Operations.Linear(feature_in=k, feature_out=1, random_init = True)
)

pnet = pden.PDENet.PDENET(net=net)
print(net)
# Out:
# Net 14:
# 	17	Linear: [1 -> 4]
# 	13	Activation funciton: <function tanh at 0x129f2edd0>
# 	5	Linear: [4 -> 1]

# %%
x = tf.placeholder(tf.float64, [None, 1])
y = pnet.forward(x)

bc_x = tf.placeholder(tf.float64, [1, 1])
bc_y = pnet.forward(bc_x)

der_gen = der(y, x, 1, 1)
dy = der_gen(0, j=[0])
dy2= der_gen(0, j=[0, 0])

bc_der = der(bc_y, bc_x, 1, 1)(0, j=[0])

# %%
pnet = pnet.add_loss(tf.reduce_mean(tf.pow(tf.exp(dy) - tf.exp(2 * x), 2)))
pnet = pnet.add_loss(tf.reduce_mean(tf.pow(bc_y, 2)), weight=1.0)

# %%
learning_rate = 5e-2
training_epochs = 2000
display_step = 250

opt = tf.train.AdamOptimizer(learning_rate = learning_rate)
train = opt.minimize(pnet.loss)

init = tf.global_variables_initializer()

# %%
X = np.linspace(0, 1, 100).reshape(-1, 1)

# %%
losses = []

# %%
sess = tf.Session()
sess.run(init)

for epoch in range(training_epochs):
    
#     P = np.random.uniform(0, 0.5, size=(1,))
    
    _, l, Y = sess.run([train, pnet.loss, y], feed_dict={
        x: X,
        bc_x: np.array([[0.0]])
    })
    
    losses.append(l)
    
    if epoch % display_step == 0 and True:
        clear_output(wait=True)
        
        print(f'Training error for net is "{l}". Epoch {epoch}')
        
        plt.plot(X.flatten(), Y.flatten(), '--r', label='Net')
        plt.plot(X.flatten(), X.flatten() ** 2, '--b', label='Analytical')
        plt.legend()
        plt.show()

        
print("Optimization Finished!")
# Out:
# Training error for net is "7.503879681387428e-05". Epoch 1750
# Optimization Finished!

# %%
plt.plot(X.flatten(), Y.flatten(), '--r', label='Net')
plt.plot(X.flatten(), X.flatten() ** 2, '--b', label='Analytical')
plt.legend()
plt.show()

# %%
# l_2_1 = losses

# %%
# l_3_1 = losses

# %%
# l_4_1 = losses

# %%
x = np.array(l_2_1[:650])
y = np.array(l_3_1[:650])
z = np.array(l_4_1[:650])

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(np.log(x), 'b', label=r'$\|h\| = 2, f(x) = th(x)1$')
plt.plot(np.log(y), 'r', label=r'$\|h\| = 3, f(x) = th(x)$')
plt.plot(np.log(z), 'g', label=r'$\|h\| = 2, f(x) = cos(x)$')
plt.grid()
plt.xlabel('#Iteration')
plt.ylabel('log E')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(X.flatten(), Y.flatten(), '--r', label='Neural network')
plt.plot(X.flatten(), X.flatten() ** 2, '--b', label='Analytical solution')
plt.legend()
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
